# %% [markdown]
# ### Safegraph Foot Traffic - Visitor Paths
#
# Author: Lydia Lo
#
# The purpose of this notebook is to plot travel routes from the most-visited locations to the nearest brand locations (e.g., Starbucks) that persons tended to visit on the same day.

# %% [markdown]
# #### Imports

# %%
# %load_ext autoreload
# %autoreload 2

# Third-party imports
import pandas as pd

# Application imports
from utils.constants import DATA_DIR
from utils.safegraph import (
    compute_fastest_routes,
    get_top_locations_with_related_brands,
    plot_routes
)

# %% [markdown]
# #### Foot Paths
#
# {Walk reader through logic and results}

# %%
# Load data file
hilo_df = pd.read_parquet(f"{DATA_DIR}/hilo_full_patterns.parquet")
top_locations = get_top_locations_with_related_brands(hilo_df)
top_locations
# Out:
#                     Safegraph Place ID                 Main Business  \
# 0  sg:20ef6cb67d8044a8819242b88ea0382d                Waiakea Center
# 1  sg:233e22fd43c045068caa4ebb0d50dfd6            Prince Kuhio Plaza
# 2  sg:e94865836761404c88783262889769da                       Walmart
# 3  sg:7d6d3d1141b54069a25505c520b82caf                        Target
# 4  sg:3597c36840414287a1a3ca04d92c0b49  University Of Hawaii At Hilo
# 5  sg:6e05b546b9f94607a9562385f2595e4a           Hilo Medical Center
# 6  sg:a59a77f25593461f9eb9d7d4a1919118                The Home Depot
# 7  sg:67245b251c3046beabbe31e530a6da4b                           CVS
# 8  sg:6dbef0623590420385f65cafb0208ba7         Kta Puainako Pharmacy
#
#    Main Latitude  Main Longitude Related Brand  Related Brand Latitude  \
# 0      19.700528     -155.062836       Walmart               19.700208
# 1      19.696705     -155.063336           CVS               19.719114
# 2      19.700208     -155.061990        Target               19.701079
# 3      19.701079     -155.060065           CVS               19.719114
# 4      19.700514     -155.080721       Safeway               19.700470
# 5      19.718494     -155.112909           CVS               19.719114
# 6      19.698058     -155.059361       Walmart               19.700208
# 7      19.696084     -155.061919       Walmart               19.700208
# 8      19.693967     -155.066875           CVS               19.719114
#
#    Related Brand Longitude
# 0              -155.061990
# 1              -155.080965
# 2              -155.060065
# 3              -155.080965
# 4              -155.060697
# 5              -155.080965
# 6              -155.061990
# 7              -155.061990
# 8              -155.080965

# %%
foot_routes = compute_fastest_routes(top_locations)
foot_routes
# Out:
#                   Main Business Related Brand  Distance  Duration  \
# 0                Waiakea Center       Walmart      43.3      12.7
# 1            Prince Kuhio Plaza           CVS    3775.3     362.1
# 2                       Walmart        Target    1039.5     149.1
# 3                        Target           CVS    3865.8     393.5
# 4  University Of Hawaii At Hilo       Safeway    3946.5     447.3
# 5           Hilo Medical Center           CVS    4295.4     466.1
# 6                The Home Depot       Walmart     587.4      98.5
# 7                           CVS       Walmart     616.1     155.1
# 8         Kta Puainako Pharmacy           CVS    3355.8     323.9
#
#                                             Geometry
# 0  [(19.70049, -155.06284), (19.70049, -155.06265...
# 1  [(19.69658, -155.06295), (19.69652, -155.06295...
# 2  [(19.70027, -155.06265), (19.70015, -155.06267...
# 3  [(19.70136, -155.06007), (19.70137, -155.05973...
# 4  [(19.70025, -155.08124), (19.70032, -155.08133...
# 5  [(19.71874, -155.11296), (19.71874, -155.11296...
# 6  [(19.69858, -155.05921), (19.69857, -155.0591)...
# 7  [(19.69609, -155.06222), (19.69621, -155.06221...
# 8  [(19.69398, -155.06669), (19.69413, -155.0667)...

# %%
plot_routes(foot_routes)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5dcc312c539e1e8806b301d77fa22a83 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div style=&quot;position: fixed;
#                 bottom: 50px; left: 50px; width: 150px; height: 90px;
#                 border:2px solid grey; z-index:9999; font-size:14px;
#                 &quot;&gt;&amp;nbsp; &lt;b&gt;Legend&lt;/b&gt; &lt;br&gt;
#                     &amp;nbsp; Main Business &amp;nbsp; &lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:red&quot;&gt;&lt;/i&gt;&lt;br&gt;
#                     &amp;nbsp; Related Brand &amp;nbsp; &lt;i class=&quot;fa fa-map-marker fa-2x&quot; style=&quot;color:blue&quot;&gt;&lt;/i&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5dcc312c539e1e8806b301d77fa22a83&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5dcc312c539e1e8806b301d77fa22a83 = L.map(
#                 &quot;map_5dcc312c539e1e8806b301d77fa22a83&quot;,
#                 {
#                     center: [19.70049, -155.06284],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 12,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_32345172b18ae9b64b46f5603535847f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_5dcc312c539e1e8806b301d77fa22a83);
#
#
#             var poly_line_ea562fbad999febdb8f38d7ede9ce061 = L.polyline(
#                 [[[19.70027, -155.06265]]],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: false, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;noClip&quot;: false, &quot;opacity&quot;: 1.0, &quot;smoothFactor&quot;: 1.0, &quot;stroke&quot;: true, &quot;weight&quot;: 5}
#             ).addTo(map_5dcc312c539e1e8806b301d77fa22a83);
#
#
#         var popup_51633a10669ebe20128421d37a28cf57 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_33a509d56b073ffb3f6a415f9bb19a23 = $(`&lt;div id=&quot;html_33a509d56b073ffb3f6a415f9bb19a23&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Route from Waiakea Center to Walmart&lt;/div&gt;`)[0];
#                 popup_51633a10669ebe20128421d37a28cf57.setContent(html_33a509d56b073ffb3f6a415f9bb19a23);
#
#
#
#         poly_line_ea562fbad999febdb8f38d7ede9ce061.bindPopup(popup_51633a10669ebe20128421d37a28cf57)
#         ;
#
#
#
#
#             var marker_b6834cfc863f44f8668a2956d74f3063 = L.marker(
#                 [19.70049, -155.06284],
#                 {}
#             ).addTo(map_5dcc312c539e1e8806b301d77fa22a83);
#
#
#             var icon_a42afbc6c038e7e98c4f0c34aeac7405 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b6834cfc863f44f8668a2956d74f3063.setIcon(icon_a42afbc6c038e7e98c4f0c34aeac7405);
#
#
#         var popup_fd927645a87ac4857dfd7707c87ae4c4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a1d6d2da887bfe6247742239c4d6298 = $(`&lt;div id=&quot;html_5a1d6d2da887bfe6247742239c4d6298&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Waiakea Center&lt;/div&gt;`)[0];
#                 popup_fd927645a87ac4857dfd7707c87ae4c4.setContent(html_5a1d6d2da887bfe6247742239c4d6298);
#
#
#
#         marker_b6834cfc863f44f8668a2956d74f3063.bindPopup(popup_fd927645a87ac4857dfd7707c87ae4c4)
#         ;
#
#
#
#
#             var marker_84cc52391c8144c2be686da0b43bc7a9 = L.marker(
#                 [19.70027, -155.06265],
#                 {}
#             ).addTo(map_5dcc312c539e1e8806b301d77fa22a83);
#
#
#             var icon_84503b3b39a8bbda071b252f23fac937 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_84cc52391c8144c2be686da0b43bc7a9.setIcon(icon_84503b3b39a8bbda071b252f23fac937);
#
#
#         var popup_8c9522f1dcfd903777dd1626d10e86ba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7b9854207d189a4e79b44b5c59ea704 = $(`&lt;div id=&quot;html_e7b9854207d189a4e79b44b5c59ea704&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Wa

# %% [markdown]
# #### Conclusions
#
# -
# -
# -
